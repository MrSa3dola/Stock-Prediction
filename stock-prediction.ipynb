# %% [markdown]
# ### Stock Market Prediction And Forecasting Using Stacked LSTM

# %%
import pandas as pd

# %%
df=pd.read_csv('/kaggle/input/aapllll/AAPL.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 symbol                       date    close     high     low  \
# 0           0   AAPL  2015-05-27 00:00:00+00:00  132.045  132.260  130.05
# 1           1   AAPL  2015-05-28 00:00:00+00:00  131.780  131.950  131.10
# 2           2   AAPL  2015-05-29 00:00:00+00:00  130.280  131.450  129.90
# 3           3   AAPL  2015-06-01 00:00:00+00:00  130.535  131.390  130.05
# 4           4   AAPL  2015-06-02 00:00:00+00:00  129.960  130.655  129.32
#
#      open    volume    adjClose     adjHigh      adjLow     adjOpen  \
# 0  130.34  45833246  121.682558  121.880685  119.844118  120.111360
# 1  131.86  30733309  121.438354  121.595013  120.811718  121.512076
# 2  131.23  50884452  120.056069  121.134251  119.705890  120.931516
# 3  131.20  32112797  120.291057  121.078960  119.844118  120.903870
# 4  129.86  33667627  119.761181  120.401640  119.171406  119.669029
#
#    adjVolume  divCash  splitFactor
# 0   45833246      0.0          1.0
# 1   30733309      0.0          1.0
# 2   50884452      0.0          1.0
# 3   32112797      0.0          1.0
# 4   33667627      0.0          1.0

# %%
df.tail()
# Out:
#       Unnamed: 0 symbol                       date   close    high       low  \
# 1253        1253   AAPL  2020-05-18 00:00:00+00:00  314.96  316.50  310.3241
# 1254        1254   AAPL  2020-05-19 00:00:00+00:00  313.14  318.52  313.0100
# 1255        1255   AAPL  2020-05-20 00:00:00+00:00  319.23  319.52  316.2000
# 1256        1256   AAPL  2020-05-21 00:00:00+00:00  316.85  320.89  315.8700
# 1257        1257   AAPL  2020-05-22 00:00:00+00:00  318.89  319.23  315.3500
#
#         open    volume  adjClose  adjHigh    adjLow  adjOpen  adjVolume  \
# 1253  313.17  33843125    314.96   316.50  310.3241   313.17   33843125
# 1254  315.03  25432385    313.14   318.52  313.0100   315.03   25432385
# 1255  316.68  27876215    319.23   319.52  316.2000   316.68   27876215
# 1256  318.66  25672211    316.85   320.89  315.8700   318.66   25672211
# 1257  315.77  20450754    318.89   319.23  315.3500   315.77   20450754
#
#       divCash  splitFactor
# 1253      0.0          1.0
# 1254      0.0          1.0
# 1255      0.0          1.0
# 1256      0.0          1.0
# 1257      0.0          1.0

# %%
df1=df.reset_index()['close']

# %%
df1
# Out:
# 0       132.045
# 1       131.780
# 2       130.280
# 3       130.535
# 4       129.960
#          ...
# 1253    314.960
# 1254    313.140
# 1255    319.230
# 1256    316.850
# 1257    318.890
# Name: close, Length: 1258, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.plot(df1)

# %%
### LSTM are sensitive to the scale of the data. so we apply MinMax scaler

# %%
import numpy as np

# %%
df1
# Out:
# 0       132.045
# 1       131.780
# 2       130.280
# 3       130.535
# 4       129.960
#          ...
# 1253    314.960
# 1254    313.140
# 1255    319.230
# 1256    316.850
# 1257    318.890
# Name: close, Length: 1258, dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
print(df1)
# Out:
# [[0.17607447]
#  [0.17495567]
#  [0.16862282]
#  ...
#  [0.96635143]
#  [0.9563033 ]
#  [0.96491598]]

# %%
##splitting dataset into train and test split
training_size=int(len(df1)*0.65)
test_size=len(df1)-training_size
train_data,test_data=df1[0:training_size,:],df1[training_size:len(df1),:1]

# %%
training_size,test_size
# Out:
# (817, 441)

# %%
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, 0,1,2,3-----99   100 
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)

# %%
# reshape into X=t,t+1,t+2,t+3 and Y=t+4
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
print(X_train.shape), print(y_train.shape)
# Out:
# (716, 100)
# (716,)
# (None, None)

# %%
print(X_test.shape), print(ytest.shape)
# Out:
# (340, 100)
# (340,)
# (None, None)

# %%
# reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %%
### Create the Stacked LSTM model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
# Out:
# 2024-02-28 03:59:09.924399: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-28 03:59:09.924497: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-28 03:59:10.060175: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(100,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 100, 50)        │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 100, 50)        │        20,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 50)             │        20,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 50,851 (198.64 KB)
#  Trainable params: 50,851 (198.64 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=100,batch_size=64)
# Out:
# Epoch 1/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - loss: 0.0292 - val_loss: 0.0785
# Epoch 2/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0041 - val_loss: 0.0066
# Epoch 3/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 8.8760e-04 - val_loss: 0.0043
# Epoch 4/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 8.3868e-04 - val_loss: 0.0060
# Epoch 5/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 6.8048e-04 - val_loss: 0.0080
# Epoch 6/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 6.4933e-04 - val_loss: 0.0075
# Epoch 7/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 6.6696e-04 - val_loss: 0.0074
# Epoch 8/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 6.1682e-04 - val_loss: 0.0058
# Epoch 9/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 5.7657e-04 - val_loss: 0.0044
# Epoch 10/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 5.8509e-04 - val_loss: 0.0050
# Epoch 11/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 6.3360e-04 - val_loss: 0.0049
# Epoch 12/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 5.8157e-04 - val_loss: 0.0040
# Epoch 13/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 6.5083e-04 - val_loss: 0.0044
# Epoch 14/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 5.6710e-04 - val_loss: 0.0052
# Epoch 15/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 5.6982e-04 - val_loss: 0.0044
# Epoch 16/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 5.4347e-04 - val_loss: 0.0037
# Epoch 17/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 5.4686e-04 - val_loss: 0.0030
# Epoch 18/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 6.4381e-04 - val_loss: 0.0035
# Epoch 19/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 5.9612e-04 - val_loss: 0.0045
# Epoch 20/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 5.5493e-04 - val_loss: 0.0035
# Epoch 21/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.8107e-04 - val_loss: 0.0040
# Epoch 22/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.8300e-04 - val_loss: 0.0027
# Epoch 23/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.7340e-04 - val_loss: 0.0029
# Epoch 24/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.4914e-04 - val_loss: 0.0023
# Epoch 25/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 5.1898e-04 - val_loss: 0.0021
# Epoch 26/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.6626e-04 - val_loss: 0.0030
# Epoch 27/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.8512e-04 - val_loss: 0.0020
# Epoch 28/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 3.8663e-04 - val_loss: 0.0019
# Epoch 29/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.6697e-04 - val_loss: 0.0023
# Epoch 30/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0500e-04 - val_loss: 0.0018
# Epoch 31/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.1615e-04 - val_loss: 0.0017
# Epoch 32/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 3.6176e-04 - val_loss: 0.0016
# Epoch 33/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.1935e-04 - val_loss: 0.0027
# Epoch 34/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.6458e-04 - val_loss: 0.0016
# Epoch 35/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 3.9509e-04 - val_loss: 0.0025
# Epoch 36/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.9731e-04 - val_loss: 0.0015
# Epoch 37/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.2067e-04 - val_loss: 0.0023
# Epoch 38/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.7319e-04 - val_loss: 0.0026
# Epoch 39/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.6732e-04 - val_loss: 0.0028
# Epoch 40/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 5.7912e-04 - val_loss: 0.0038
# Epoch 41/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.7290e-04 - val_loss: 0.0014
# Epoch 42/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.6468e-04 - val_loss: 0.0015
# Epoch 43/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 3.4285e-04 - val_loss: 0.0021
# Epoch 44/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.4263e-04 - val_loss: 0.0016
# Epoch 45/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.0047e-04 - val_loss: 0.0017
# Epoch 46/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.5008e-04 - val_loss: 0.0015
# Epoch 47/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 3.3365e-04 - val_loss: 0.0024
# Epoch 48/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 3.4035e-04 - val_loss: 0.0019
# Epoch 49/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 3.0358e-04 - val_loss: 0.0015
# Epoch 50/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 3.0702e-04 - val_loss: 0.0021
# Epoch 51/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.8153e-04 - val_loss: 0.0021
# Epoch 52/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 3.2932e-04 - val_loss: 0.0013
# Epoch 53/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 3.0096e-04 - val_loss: 0.0016
# Epoch 54/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.8395e-04 - val_loss: 0.0015
# Epoch 55/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.6499e-04 - val_loss: 0.0017
# Epoch 56/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 3.1723e-04 - val_loss: 0.0019
# Epoch 57/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.9017e-04 - val_loss: 0.0015
# Epoch 58/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.7520e-04 - val_loss: 0.0012
# Epoch 59/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.6577e-04 - val_loss: 0.0012
# Epoch 60/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.7126e-04 - val_loss: 0.0013
# Epoch 61/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.5818e-04 - val_loss: 0.0013
# Epoch 62/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.4808e-04 - val_loss: 0.0025
# Epoch 63/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.6551e-04 - val_loss: 0.0012
# Epoch 64/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.4336e-04 - val_loss: 0.0023
# Epoch 65/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.3724e-04 - val_loss: 0.0011
# Epoch 66/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.3626e-04 - val_loss: 0.0018
# Epoch 67/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.1567e-04 - val_loss: 0.0013
# Epoch 68/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.3032e-04 - val_loss: 0.0012
# Epoch 69/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.5013e-04 - val_loss: 0.0017
# Epoch 70/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.2697e-04 - val_loss: 0.0012
# Epoch 71/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2.3249e-04 - val_loss: 0.0011
# Epoch 72/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.8358e-04 - val_loss: 0.0015
# Epoch 73/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.0690e-04 - val_loss: 0.0012
# Epoch 74/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.1771e-04 - val_loss: 0.0011
# Epoch 75/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.9197e-04 - val_loss: 0.0020
# Epoch 76/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 3.0430e-04 - val_loss: 0.0014
# Epoch 77/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.1518e-04 - val_loss: 0.0012
# Epoch 78/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.0079e-04 - val_loss: 0.0015
# Epoch 79/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.2397e-04 - val_loss: 0.0014
# Epoch 80/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.0489e-04 - val_loss: 0.0010
# Epoch 81/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.5787e-04 - val_loss: 9.4785e-04
# Epoch 82/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.3180e-04 - val_loss: 0.0012
# Epoch 83/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.9945e-04 - val_loss: 9.4451e-04
# Epoch 84/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.8618e-04 - val_loss: 9.8429e-04
# Epoch 85/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.1876e-04 - val_loss: 0.0015
# Epoch 86/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.0555e-04 - val_loss: 8.8628e-04
# Epoch 87/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.8774e-04 - val_loss: 8.6277e-04
# Epoch 88/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.5757e-04 - val_loss: 8.8165e-04
# Epoch 89/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.6585e-04 - val_loss: 9.0936e-04
# Epoch 90/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.4208e-04 - val_loss: 8.4608e-04
# Epoch 91/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.6531e-04 - val_loss: 8.2402e-04
# Epoch 92/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.5320e-04 - val_loss: 8.8478e-04
# Epoch 93/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.6369e-04 - val_loss: 9.4548e-04
# Epoch 94/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.4941e-04 - val_loss: 9.8111e-04
# Epoch 95/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.5698e-04 - val_loss: 0.0012
# Epoch 96/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.9073e-04 - val_loss: 0.0012
# Epoch 97/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.9573e-04 - val_loss: 0.0012
# Epoch 98/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.7839e-04 - val_loss: 0.0011
# Epoch 99/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.1010e-04 - val_loss: 8.7663e-04
# Epoch 100/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.5163e-04 - val_loss: 7.6109e-04

# %%
import tensorflow as tf

# %%
### Lets Do the prediction and check performance metrics
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %%
##Transformback to original form
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

# %%
### Calculate RMSE performance metrics
import math
from sklearn.metrics import mean_squared_error
math.sqrt(mean_squared_error(y_train,train_predict))
# Out:
# 141.6854384691364

# %%
### Test Data RMSE
math.sqrt(mean_squared_error(ytest,test_predict))
# Out:
# 238.05023312284206

# %%
### Plotting 
# shift train predictions for plotting
look_back=100
trainPredictPlot = numpy.empty_like(df1)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict)+look_back, :] = train_predict
# shift test predictions for plotting
testPredictPlot = numpy.empty_like(df1)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(df1)-1, :] = test_predict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(df1))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %%
len(test_data)
# Out:
# 441

# %%
x_input=test_data[341:].reshape(1,-1)
x_input.shape
# Out:
# (1, 100)

# %%
temp_input=list(x_input)
temp_input=temp_input[0].tolist()

# %%
# demonstrate prediction for next 10 days
from numpy import array

lst_output=[]
n_steps=100
i=0
while(i<30):
    
    if(len(temp_input)>100):

        x_input=np.array(temp_input[1:])
        print("{} day input {}".format(i,x_input))
        x_input=x_input.reshape(1,-1)
        x_input = x_input.reshape((1, n_steps, 1))

        yhat = model.predict(x_input, verbose=0)
        print("{} day output {}".format(i,yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        #print(temp_input)
        lst_output.extend(yhat.tolist())
        i=i+1
    else:
        x_input = x_input.reshape((1, n_steps,1))
        yhat = model.predict(x_input, verbose=0)
        print(yhat[0])
        print(len(temp_input))
        lst_output.extend(yhat.tolist())
        i += 1
    
print(lst_output)
# Out:
# [0.9661455]
# 100
# [0.9661455]
# 100
# [0.9661455]
# 100
# [0.9661455]
# 100
# [0.9661455]
# 100
# [0.9661455]
# 100
# [0.9661455]
# 100
# [0.9661455]
# 100
# [0.9661455]
# 100
# [0.9661455]
# 100
# [0.9661455]
# 100
# [0.9661455]
# 100
# [0.9661455]
# 100
# [0.9661455]
# 100
# [0.9661455]
# 100
# [0.9661455]
# 100
# [0.9661455]
# 100
# [0.9661455]
# 100
# [0.9661455]
# 100
# [0.9661455]
# 100
# [0.9661455]
# 100
# [0.9661455]
# 100
# [0.9661455]
# 100
# [0.9661455]
# 100
# [0.9661455]
# 100
# [0.9661455]
# 100
# [0.9661455]
# 100
# [0.9661455]
# 100
# [0.9661455]
# 100
# [0.9661455]
# 100
# [[0.9661455154418945], [0.9661455154418945], [0.9661455154418945], [0.9661455154418945], [0.9661455154418945], [0.9661455154418945], [0.9661455154418945], [0.9661455154418945], [0.9661455154418945], [0.9661455154418945], [0.9661455154418945], [0.9661455154418945], [0.9661455154418945], [0.9661455154418945], [0.9661455154418945], [0.9661455154418945], [0.9661455154418945], [0.9661455154418945], [0.9661455154418945], [0.9661455154418945], [0.9661455154418945], [0.9661455154418945], [0.9661455154418945], [0.9661455154418945], [0.9661455154418945], [0.9661455154418945], [0.9661455154418945], [0.9661455154418945], [0.9661455154418945], [0.9661455154418945]]

# %%
day_new=np.arange(1,101)
day_pred=np.arange(101,131)

# %%
import matplotlib.pyplot as plt

# %%
len(df1)
# Out:
# 1258

# %%
plt.plot(day_new,scaler.inverse_transform(df1[1158:]))
plt.plot(day_pred,scaler.inverse_transform(lst_output))

# %%
df3=df1.tolist()
df3.extend(lst_output)
plt.plot(df3[1200:])

# %%
df3=scaler.inverse_transform(df3).tolist()

# %%
plt.plot(df3)
